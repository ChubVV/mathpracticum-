# %% [markdown]
# <a href="https://colab.research.google.com/github/ChubVV/mathpracticum-/blob/hometask3/hometask3_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1mGXCNLa1hkdcmcMnQz3tg8mqb_NkFOFe?usp=sharing)

# %% [markdown]
# The data in [populations.txt](http://www.scipy-lectures.org/_downloads/populations.txt) describes the populations of hares, lynxes and carrots in northern Canada during 20 years. Get the data with ```np.loadtxt``` and do the following exercises **without for-loops**.

# %% [markdown]
# Plot the populations for the years in the period. Add legend and axis labels to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
years = data[:,0]
plt.plot(years, data[:,1], label = 'Hare')
plt.plot(years, data[:,2], label = 'Lynx')
plt.plot(years, data[:,3], label = 'Carrot')
plt.xticks(years.astype(int)[::5])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Assuming total population of hares and lynxes is 100%, plot stacked bar graph showing ratio of each specis for the years in the period.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
years = data[:,0]
sum = data[:,1]+data[:,2]+data[:,3]
plt.bar(years,data[:,1]/sum, label = 'Hare')
plt.bar(years,data[:,2]/sum,bottom = data[:,1]/sum, label = 'Lynx')
plt.bar(years,data[:,3]/sum,bottom = data[:,2]/sum+data[:,1]/sum, label = 'Carrot')
plt.legend()
plt.show()

# %% [markdown]
# Find the mean and std of the populations of each species. Plot the historgam of population for each species and show mean values with vertical line. Arrange 3 subplots in a row.

# %%
print('mean of hare population:', np.mean(data[:, 1]))
print('std of hare population:', np.std(data[:, 1]))
print('mean of lynx population:', np.mean(data[:, 2]))
print('std of lynx population:', np.std(data[:, 2]))
print('mean of carrot population:', np.mean(data[:, 3]))
print('std of carrot population:', np.std(data[:, 3]))
fig, ax = plt.subplots(1, 3)
ax[0].hist(data[:, 1], color = 'g', label='hare')
ax[0].axvline(data[:,1].mean(), c="black")
ax[0].legend()
ax[1].hist(data[:, 2], label = 'Lynx', color = 'r')
ax[1].axvline(data[:,2].mean(), c="black")
ax[1].legend()
ax[2].hist(data[:, 3], color = 'orange', label='carrot')
ax[2].axvline(data[:,3].mean(), c="black")
ax[2].legend()
plt.show()
# Out:
# mean of hare population: 34080.95238095238
# std of hare population: 20897.906458089667
# mean of lynx population: 20166.666666666668
# std of lynx population: 16254.591536908763
# mean of carrot population: 42400.0
# std of carrot population: 3322.5062255844787

# %% [markdown]
# Find which year each species had the largest population. Mark these years in the plot of populations.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
years = data[:,0]
print('Hares: ' + str(int(data[np.argmax(data[:, 1])][0])))
print('Lynxes: ' + str(int(data[np.argmax(data[:, 2])][0])))
print('Carrots: ' + str(int(data[np.argmax(data[:, 3])][0])))
plt.plot(years, data[:,1], label = 'Hare')
plt.plot(years, data[:,2], label = 'Lynx')
plt.plot(years, data[:,3], label = 'Carrot')
plt.axvline(years[np.argmax(data[:,1])], c = 'r')
plt.axvline(years[np.argmax(data[:,2])], c = 'r')
plt.axvline(years[np.argmax(data[:,3])], c = 'r')
plt.xticks([years[np.argmax(data[:,1])],years[np.argmax(data[:,2])],years[np.argmax(data[:,3])]],rotation = 90)
plt.legend()
plt.show()
# Out:
# Hares: 1903
# Lynxes: 1904
# Carrots: 1900

# %% [markdown]
# Find which species (hares or lynxes) has the largest population for each year. Print the result as [H, H, L, H, ...]. Plot a pie chart showing ratio of "H" and "L" values obtained.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
a = np.where(data[:, 1] - data[:, 2] > 0, 'H', 'L')
p = np.array([len(np.argwhere(a == 'H')), len(np.argwhere(a == 'L'))])
plt.pie(p, autopct='%1.f%%')
plt.show()
print(a)
# Out:
# ['H' 'H' 'H' 'H' 'L' 'L' 'L' 'H' 'H' 'H' 'H' 'H' 'H' 'H' 'H' 'L' 'L' 'L'
#  'H' 'H' 'H']

# %% [markdown]
# Find which years any of the populations is above 50000. Show time periods where populations are above 50000
# in the plot of populations.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
years = data[:,0]
plt.xlabel('Year')
plt.ylabel('Population')
plt.plot(years, data[:, 1], label = "hares")
plt.plot(years, data[:, 2], label = "lynxes")
plt.plot(years, data[:, 3], label = "carrots")
plt.axhline(y=50000, c='black', linestyle='--', linewidth=4)
plt.scatter(data[data[:, 1] > 50000, 0], data[:, 1] [data[:, 1] > 50000])
plt.scatter(data[data[:, 2] > 50000, 0], data[:, 2] [data[:, 2] > 50000])
plt.scatter(data[data[:, 3] > 50000, 0], data[:, 3] [data[:, 3] > 50000])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Find the top 2 years for each species when they had the lowest populations.

# %%
data[data[:, 1:].argsort(axis=0)[:2], 0]
# Out:
# array([[1917., 1900., 1916.],
#        [1916., 1901., 1903.]])

# %% [markdown]
# Plot the change in hare population and the number of lynxes. Find the correlation coefficient.

# %%
fig, ax = plt.subplots(1, 2)
years= data[:,0]
ax[0].bar(years - 0.2, data[:, 1], 0.4, color='g', label='Hare')
ax[0].bar(years + 0.2, data[:, 2], 0.4, color='r', label='Lynxes')
ax[0].legend()
ax[1].bar(years- 0.2, data[:, 1], 0.4, color='g', label='Hare')
ax[1].bar(years + 0.2, data[:, 3], 0.4, color='orange', label='Carrots')
ax[1].legend()
plt.show()

# %% [markdown]
# Show population of hares vs carrots and hares vs lynxes.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
year = data[:,0]
fig,ax = plt.subplots(1,3, sharey = True)
ax[0].plot(years, data[:,1], label = 'Hare')
ax[1].plot(years, data[:,2], label = 'Lynx', c = 'orange')
ax[2].plot(years, data[:,3], label = 'Carrots', c ='green')
fig.suptitle('Hares vs Lynx vs Carrots')
plt.show()

# %% [markdown]
# Assume the population of hares in 1920 is unknown. Suggest a way to estimate this value. Compare an estimated value
# with the true value and print a ratio of the error to the true value.

# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('http://scipy-lectures.org/_downloads/populations.txt')
year = data[:,0] 
hare = data[:,1]
print('Predicted 1920 value is', hare[10])
print('Real 1920 value is', hare[20])
print('Median is',np.median(hare))
print('The error according to the periodicy is',abs((hare[20]-hare[10])/hare[20]))
print('The error for median is', abs((hare[20]-np.median(hare))/hare[20]))
# Out:
# Predicted 1920 value is 27100.0
# Real 1920 value is 24700.0
# Median is 25400.0
# The error according to the periodicy is 0.09716599190283401
# The error for median is 0.02834008097165992
